# %% [markdown]
# # Introduction Section of Course
#
# ## What is Power BI
#
# Provides an interface for Transforming, Visualizing and Analyzing data through reports.
#
# ![steps_and_features_example](attachment:image-2.png)
#
#
# Power BI has 3 primary options to use Power BI with the Desktop installation being the most feature rich and where most engineering is completed.
#
# ![powerbi_platform_and_features_example](attachment:image.png)
